# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephJoest/2-CORTE-PROGRAMACION-III---PROYECTO-/blob/main/Exercise%2012.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a complete Jupyter notebook for the final project and save it to /mnt/data

import nbformat as nbf

nb = nbf.v4.new_notebook()
nb['metadata'] = {
    "kernelspec": {
        "display_name": "Python 3",
        "language": "python",
        "name": "python3"
    },
    "language_info": {
        "name": "python",
        "version": "3.x"
    }
}

cells = []

# Exercise 2 - Title
cells.append(nbf.v4.new_markdown_cell("""# Data Science Tools and Ecosystem"""))

# Exercise 3 - Introduction
cells.append(nbf.v4.new_markdown_cell("""
In this notebook, Data Science tools and techniques are summarized. We will explore popular languages, libraries, and tools used by data scientists and run a few simple code examples.
"""))

# Exercise 4 - Data Science Languages
cells.append(nbf.v4.new_markdown_cell("""
## Data Science Languages
Some of the popular languages used by Data Scientists include:
1. Python
2. R
3. SQL
4. Julia
5. Scala
"""))

# Exercise 5 - Data Science Libraries
cells.append(nbf.v4.new_markdown_cell("""
## Data Science Libraries
Commonly used libraries for Data Science include:
- NumPy
- Pandas
- Matplotlib
- Seaborn
- Scikit-learn
- TensorFlow
- PyTorch
"""))

# Exercise 6 - Table of Data Science Tools
cells.append(nbf.v4.new_markdown_cell("""
## Data Science Tools
| Tool              | Category                  | Notes                                   |
|-------------------|---------------------------|-----------------------------------------|
| Jupyter Notebook  | Interactive Development   | Literate programming & reproducibility  |
| JupyterLab        | Interactive Development   | Multi-document interface                |
| RStudio           | Statistical Analysis      | Great for R language                    |
| Apache Spark      | Big Data Processing       | Distributed computing                   |
| TensorFlow        | Machine Learning/Deep NN  | Model building & training               |
| Git/GitHub        | Version Control/Sharing   | Collaboration & publishing              |
"""))

# Exercise 7 - Arithmetic expressions examples (Markdown)
cells.append(nbf.v4.new_markdown_cell("""
### Examples of Arithmetic Expressions
Below are examples of arithmetic operations like **addition** and **multiplication**.
"""))

# Exercise 8 - Code cell multiply then add
cells.append(nbf.v4.new_code_cell("""# This a simple arithmetic expression to multiply then add integers
(3 * 4) + 5"""))

# Exercise 9 - Code cell convert minutes to hours
cells.append(nbf.v4.new_markdown_cell("""
### Convert Minutes to Hours
The following code converts **200 minutes** into **hours** by dividing by 60.
"""))
cells.append(nbf.v4.new_code_cell("""# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
hours"""))

# Exercise 10 - Objectives
cells.append(nbf.v4.new_markdown_cell("""
## Objectives
- List popular languages for Data Science
- List commonly used libraries in Data Science
- Create a table with common Data Science tools
- Demonstrate basic arithmetic expressions
- Convert minutes to hours using Python code
- Share this notebook publicly on GitHub
"""))

# Exercise 11 - Author
cells.append(nbf.v4.new_markdown_cell("""
## Author
*Joseph Amaya*
"""))

nb['cells'] = cells

path = "/mnt/data/DataScienceEcosystem.ipynb"
with open(path, "w", encoding="utf-8") as f:
    nbf.write(nb, f)

path
